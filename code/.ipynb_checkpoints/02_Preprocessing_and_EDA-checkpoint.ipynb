# %% [markdown]
# # Capstone Project: Classifying clinically actionable genetic mutations
#
# ***

# %% [markdown]
# # Step 2: Pre-processing & Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Importing of Libraries

# %%
# pip install imblearn

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn import metrics
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, HashingVectorizer

from sklearn.utils import resample

from imblearn.over_sampling import SMOTE

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

from bs4 import BeautifulSoup
import nltk
from nltk.tokenize import RegexpTokenizer
import regex as re
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords

from collections import Counter
from wordcloud import WordCloud

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %% [markdown]
# ## Data Import

# %%
# Import the datasets
train = pd.read_csv("../assets/train_clean.csv", keep_default_na=False)
test = pd.read_csv("../assets/test_clean.csv", keep_default_na=False)

# %%
train.shape, test.shape
# Out:
# ((3321, 5), (5668, 4))

# %%
train.head()
# Out:
#    id                                               text    gene  \
# 0   0  Cyclin-dependent kinases (CDKs) regulate a var...  FAM58A
# 1   1   Abstract Background  Non-small cell lung canc...     CBL
# 2   2   Abstract Background  Non-small cell lung canc...     CBL
# 3   3  Recent evidence has demonstrated that acquired...     CBL
# 4   4  Oncogenic mutations in the monomeric Casitas B...     CBL
#
#               variation  class
# 0  Truncating Mutations      1
# 1                 W802*      2
# 2                 Q249E      2
# 3                 N454D      3
# 4                 L399V      4

# %%
test.head()
# Out:
#    id                                               text     gene variation
# 0   0  2. This mutation resulted in a myeloproliferat...    ACSL4     R570S
# 1   1   Abstract The Large Tumor Suppressor 1 (LATS1)...    NAGLU     P521L
# 2   2  Vascular endothelial growth factor receptor (V...      PAH     L333F
# 3   3  Inflammatory myofibroblastic tumor (IMT) is a ...     ING1     A148D
# 4   4   Abstract Retinoblastoma is a pediatric retina...  TMEM216      G77A

# %% [markdown]
# ## Pre-processing

# %% [markdown]
# ### Text Lemmatisation

# %%
# We define a function to preprocess the text
def preprocess(input_string):
    text_lower = BeautifulSoup(input_string).get_text().lower()
    return re.sub("[^a-zA-Z]", " ", text_lower) # we lower the case, and remove punctuation

# %%
def lemmatize(input_string):
    
    # Lemmatise each word of text
    tokenizer = RegexpTokenizer(r'\w+')
    tokens = tokenizer.tokenize(input_string)
    lemmatizer = WordNetLemmatizer()
    tokens_lem = [lemmatizer.lemmatize(i) for i in tokens]

    # Remove stopwords
    
    stopwords = nltk.corpus.stopwords.words('english')
    new_stop_words = ['mutation', 'figure', 'fig', 'tumor', 'cell', 'patient']
    stopwords.extend(new_stop_words)
    
    stops = set(stopwords)
    
    meaningful_words = [w for w in tokens_lem if not w in stops]
    
    # Join the words back into one string separated by space, and return the result
    return(" ".join(meaningful_words))

# %%
# %%time
train['text_preproc'] = [preprocess(i) for i in list(train['text'])]
test['text_preproc'] = [preprocess(i) for i in list(test['text'])]
# Out:
# Wall time: 1min 3s

# %%
# %%time
# Add new columns to hold lemmatised text
train['lemm_text'] = [lemmatize(i) for i in list(train['text_preproc'])]
test['lemm_text'] = [lemmatize(i) for i in list(test['text_preproc'])]
# Out:
# Wall time: 4min 9s

# %%
train.head()
# Out:
#    id                                               text    gene  \
# 0   0  Cyclin-dependent kinases (CDKs) regulate a var...  FAM58A
# 1   1   Abstract Background  Non-small cell lung canc...     CBL
# 2   2   Abstract Background  Non-small cell lung canc...     CBL
# 3   3  Recent evidence has demonstrated that acquired...     CBL
# 4   4  Oncogenic mutations in the monomeric Casitas B...     CBL
#
#               variation  class  \
# 0  Truncating Mutations      1
# 1                 W802*      2
# 2                 Q249E      2
# 3                 N454D      3
# 4                 L399V      4
#
#                                         text_preproc  \
# 0  cyclin dependent kinases  cdks  regulate a var...
# 1  abstract background  non small cell lung cance...
# 2  abstract background  non small cell lung cance...
# 3  recent evidence has demonstrated that acquired...
# 4  oncogenic mutations in the monomeric casitas b...
#
#                                            lemm_text
# 0  cyclin dependent kinase cdks regulate variety ...
# 1  abstract background non small lung cancer nscl...
# 2  abstract background non small lung cancer nscl...
# 3  recent evidence ha demonstrated acquired unipa...
# 4  oncogenic monomeric casitas b lineage lymphoma...

# %%
test.head()
# Out:
#    id                                               text     gene variation  \
# 0   0  2. This mutation resulted in a myeloproliferat...    ACSL4     R570S
# 1   1   Abstract The Large Tumor Suppressor 1 (LATS1)...    NAGLU     P521L
# 2   2  Vascular endothelial growth factor receptor (V...      PAH     L333F
# 3   3  Inflammatory myofibroblastic tumor (IMT) is a ...     ING1     A148D
# 4   4   Abstract Retinoblastoma is a pediatric retina...  TMEM216      G77A
#
#                                         text_preproc  \
# 0     this mutation resulted in a myeloproliferat...
# 1  abstract the large tumor suppressor    lats   ...
# 2  vascular endothelial growth factor receptor  v...
# 3  inflammatory myofibroblastic tumor  imt  is a ...
# 4  abstract retinoblastoma is a pediatric retinal...
#
#                                            lemm_text
# 0  resulted myeloproliferative phenotype includin...
# 1  abstract large suppressor lat serine threonine...
# 2  vascular endothelial growth factor receptor ve...
# 3  inflammatory myofibroblastic imt neoplasm typi...
# 4  abstract retinoblastoma pediatric retinal init...

# %%
# Remove the redundant 'text'-related columns
train.drop(columns=['text', 'text_preproc'], inplace=True)
test.drop(columns=['text', 'text_preproc'], inplace=True)

# %%
# Rename the lemm_text columns
train.rename(columns={'lemm_text':'text'}, inplace=True)
test.rename(columns={'lemm_text':'text'}, inplace=True)

# %% [markdown]
# ## EDA on lemmatised text

# %% [markdown]
# ### Word Cloud for descriptive text

# %%
train.head()
# Out:
#    id    gene             variation  class  \
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4
#
#                                                 text
# 0  cyclin dependent kinase cdks regulate variety ...
# 1  abstract background non small lung cancer nscl...
# 2  abstract background non small lung cancer nscl...
# 3  recent evidence ha demonstrated acquired unipa...
# 4  oncogenic monomeric casitas b lineage lymphoma...

# %%
def word_count(input_string):
    tokenizer = RegexpTokenizer(r'[A-Za-z0-9]{2,}')
    words = tokenizer.tokenize(input_string)
    counter.update(words)

# %%
# Create a word frequency dictionary for class 7 variations
counter = Counter()
for input_string in train['text']:
    word_count(input_string)
train_word_freq = dict(counter.most_common())

# %%
# Determine size of word frequency dictionary
len(counter)
# Out:
# 84275

# %%
# Generate a word cloud image
wordcloud = WordCloud(max_font_size=60, background_color ='white', min_font_size = 8).generate_from_frequencies(train_word_freq)
plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Word Cloud for Descriptive Text in Training Dataset")
plt.show()

# %% [markdown]
# ### Histogram of 20 most frequent words in Training Dataset

# %%
labels, values = zip(*train_word_freq.items())
# sort your values in descending order
indSort = np.argsort(values)[::-1]
# rearrange your data
labels = np.array(labels)[indSort][:20]
values = np.array(values)[indSort][:20]
indexes = np.arange(len(labels))

# %%
plt.figure(figsize=(12,5))
sns.barplot(indexes, values);
plt.xticks(indexes, labels, rotation=45);
plt.xlabel("Word in Descriptive Text")
plt.ylabel("Number of occurrences")
plt.title("Histogram of Word Frequencies in Training Dataset");

# %% [markdown]
# ## Readiness of Pre-processed Data for Modelling

# %%
train.shape, test.shape
# Out:
# ((3321, 5), (5668, 4))

# %% [markdown]
# - Both the training and testing datasets have undergone cleaning and lemmatisation.
# - We deem the volume and quality of the training and testing datasets to be sufficient for subsequent modelling, noting that the oversampling may have lowered bias, but may increase variance.

# %% [markdown]
# ## Data Export

# %%
train.to_csv("../assets/train_prep.csv", index=False)
test.to_csv("../assets/test_prep.csv", index=False)
